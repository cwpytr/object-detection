# %% [markdown]
# # YOLO Model Training

# %% [markdown]
# ## Install requirements

# %%
# install library
# !pip install -r ./yolov5/requirements.txt
# Out:
# ...
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# ...
# Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ...
#   WARNING: Failed to remove contents in a temporary directory 'E:\my_project\YOLO\tf\Lib\site-packages\~.mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'E:\my_project\YOLO\tf\Lib\site-packages\~0mpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.16.1 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.2.6 which is incompatible.

# %% [markdown]
# ## Train Model

# %%
# !python yolov5/train.py --data data.yaml --cfg yolov5/models/yolov5s.yaml --batch-size 8 --name Model --epochs 100 --workers 0 --device 0
# Out:
# e:\my_project\Object Detection\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# Traceback (most recent call last):
#   File "e:\my_project\Object Detection\venv\lib\site-packages\tensorboard\compat\__init__.py", line 42, in tf
#     from tensorboard.compat import notf  # noqa: F401
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (e:\my_project\Object Detection\venv\lib\site-packages\tensorboard\compat\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# Traceback (most recent call last):
#   File "e:\my_project\Object Detection\venv\lib\site-packages\tensorboard\compat\__init__.py", line 42, in tf
# ...

# %% [markdown]
# ## Export Model

# %%
# !python yolov5/export.py --weights yolov5/runs/train/Model12/weights/best.pt --include torchscript onnx
# Out:
# e:\my_project\Object Detection\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# export: data=E:\my_project\Object Detection\yolov5\data\coco128.yaml, weights=['yolov5/runs/train/Model12/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# fatal: cannot change to 'E:\my_project\Object': No such file or directory
# YOLOv5  2025-8-4 Python-3.10.0 torch-2.7.1+cu118 CPU
#
# Fusing layers...
# ...
